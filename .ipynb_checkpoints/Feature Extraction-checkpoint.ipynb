# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.io import wavfile
from IPython.display import Audio
#allows for playing of audio
import librosa
import librosa.display
#allows for spectrographs and other audio manipulation
import pandas as pd
from pydub import AudioSegment
#allows for audio file slicing
import math
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-16-50ddb8b6bdfc> in <module>
#       8 #allows for spectrographs and other audio manipulation
#       9 import pandas as pd
# ---> 10 from pydub import AudioSegment
#      11 #allows for audio file slicing
#      12 import math
#
# ModuleNotFoundError: No module named 'pydub'

# %%
aj2 = pd.read_csv(r"C:\Users\njfur\Desktop\Capstone Project\A. jubatus\AJ2.csv")
aj3 = pd.read_csv(r"C:\Users\njfur\Desktop\Capstone Project\A. jubatus\AJ3.csv")
aj5 = pd.read_csv(r"C:\Users\njfur\Desktop\Capstone Project\A. jubatus\AJ5.csv")
aj13 = pd.read_csv(r"C:\Users\njfur\Desktop\Capstone Project\A. jubatus\AJ13.csv")
aj2_sound, aj2_rate = librosa.load(r"C:\Users\njfur\Desktop\Capstone Project\A. jubatus\Acinonyx_jubatus_S0612_02.wav")
aj3_sound, aj3_rate = librosa.load(r"C:\Users\njfur\Desktop\Capstone Project\A. jubatus\Acinonyx_jubatus_S1121_03.wav")
aj5_sound, aj5_rate = librosa.load(r"C:\Users\njfur\Desktop\Capstone Project\A. jubatus\Acinonyx_jubatus_S1121_05.wav")
aj13_sound, aj13_rate = librosa.load(r"C:\Users\njfur\Desktop\Capstone Project\A. jubatus\Acinonyx_jubatus_S1366_13.wav")
#Acinonyx files

# %%
AJ2 = (aj2, aj2_sound)
AJ3 = (aj3, aj3_sound)
AJ5 = (aj5, aj5_sound)
AJ13 = (aj13, aj13_sound)
#Acinonyx files continued

# %%
C1 = pd.read(r"C:\Users\njfur\Desktop\Capstone Project\Caracal\C1.csv")
C1_sound , C1_rate = librosa.load(r"C:\Users\njfur\Desktop\Capstone Project\Caracal\Caracal_1_Male_Growl+Hiss.wav")
C2 = pd.read(r"C:\Users\njfur\Desktop\Capstone Project\Caracal\C2.csv")
C2_sound , C2_rate = librosa.load(r"C:\Users\njfur\Desktop\Capstone Project\Caracal\Caracal_2_Male_Growl+Hiss.wav")
C3 = pd.read(r"C:\Users\njfur\Desktop\Capstone Project\Caracal\C3.csv")
C3_sound , C3_rate = librosa.load(r"C:\Users\njfur\Desktop\Capstone Project\Caracal\Caracal_3___Growl+Hiss.wav")
C4 = pd.read(r"C:\Users\njfur\Desktop\Capstone Project\Caracal\C4.csv")
C4_sound , C4_rate = librosa.load(r"C:\Users\njfur\Desktop\Capstone Project\Caracal\Caracal_4___Growl.m4a")
C5 = pd.read(r"C:\Users\njfur\Desktop\Capstone Project\Caracal\C5.csv")
C5_sound , C5_rate = librosa.load(r"C:\Users\njfur\Desktop\Capstone Project\Caracal\Caracal_5___Hiss+Growl.wav")
C6 = pd.read(r"C:\Users\njfur\Desktop\Capstone Project\Caracal\C6.csv")
C6_sound , C6_rate = librosa.load(r"C:\Users\njfur\Desktop\Capstone Project\Caracal\Caracal_6___Hiss+Growl.wav")
#Caracal files
C1T = (C1, C1_sound)
C2T = (C2, C2_sound)
C3T = (C3, C3_sound)
C4T = (C4, C4_sound)
C5T = (C5, C5_sound)
C6T = (C6, C6_sound)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-769322bbfce9> in <module>
# ----> 1 C1 = pd.read(r"C:\Users\njfur\Desktop\Capstone Project\Domestica\D1.csv")
#       2 D2 = pd.read(r"C:\Users\njfur\Desktop\Capstone Project\Domestica\D2.csv")
#       3 D2 = pd.read(r"C:\Users\njfur\Desktop\Capstone Project\Domestica\D2.csv")
#       4 D2 = pd.read(r"C:\Users\njfur\Desktop\Capstone Project\Domestica\D2.csv")
#       5 #Caracal files
#
# NameError: name 'pd' is not defined

# %%
D1 = pd.read(r"C:\Users\njfur\Desktop\Capstone Project\Domestica\D1.csv")
D1_sound , D1_rate = librosa.load(r"C:\Users\njfur\Desktop\Capstone Project\Domestica\Felis_silvestris_f_domestica_S0050_01_pair_adult_hiss,growl.wav")
D2 = pd.read(r"C:\Users\njfur\Desktop\Capstone Project\Domestica\D2.csv")
D2_sound , D2_rate = librosa.load(r"C:\Users\njfur\Desktop\Capstone Project\Domestica\Felis_silvestris_f_domestica_S0013_01.female_adult_hiss,call,growlwav.wav")
D3 = pd.read(r"C:\Users\njfur\Desktop\Capstone Project\Domestica\D3.csv")
D3_sound , D3_rate = librosa.load(r"C:\Users\njfur\Desktop\Capstone Project\Domestica\Felis_silvestris_f_domestica_S0002_01_short_female_adult_growl, hiss.mp3")
D4 = pd.read(r"C:\Users\njfur\Desktop\Capstone Project\Domestica\D4.csv")
D4_sound, D4_rate = librosa.load(r"C:\Users\njfur\Desktop\Capstone Project\Domestica\Felis_silvestris_f_domestica_DIG0089_01_male_juvenile_call,purr.wav")
D5 = pd.read(r"C:\Users\njfur\Desktop\Capstone Project\Domestica\D5.csv")
D5_sound, D5_rate = librosa.load(r"C:\Users\njfur\Desktop\Capstone Project\Domestica\Felis_silvestris_f_domestica_DIG0015_14_male_juvenile_purrpurr.wav")
#Domestica files
D1T = (D1, D1_sound)
D2T = (D2, D2_sound)
D3T = (D3, D3_sound)
D4T = (D4, D4_sound)
D5T = (D5, D5_sound)

# %%
#L lynx audio files

# %%
#Lynx Rufus

# %%
#Leopardus Pardalis

# %%
audio_list = [AJ2, AJ3, AJ5, AJ13, D1T, D2T, D3T, D4T, D5T, C1T, C2T, C3T, C4T, C5T, C6T]

# %%
def time_sec(time):
    (m, s) = time.split(':')
    return int(m) * 60 + round(float(s))

# %%
time_sec('1:01.7')
# Out:
# 62

# %%
def feature_extractor(file, species, sex, age, lst_calls, lst_start, lst_end, sr = 22050):
    data = []
    for x in range(len(lst_start)):
        temp = file[lst_start[x] * sr :lst_end[x] *sr]
        zeros = sum(librosa.zero_crossings(temp))
        duration = lst_end[x]-lst_start[x]
        amplitude_range = max(temp)-min(temp)
        average_amp = np.mean(temp)
        data.append([amplitude_range, average_amp, duration, zeros, species, sex, age, lst_calls[x]])
    output = pd.DataFrame(data, columns = ['Amp_range','Avg_amp','Duration','Zero_Crossings', 'Species', 'Sex', 'Age', 'Call'])
    return output

# %%
#Pass in a list of tuples, each tuple should contain two items, the first item will be the dataframe of the times
#the second item should be the audio file itself
def audio_feat_extractor(lst_tup):
    data = []
    for tup in lst_tup:
        csv = tup[0]
        audio = tup[1]
        for x, y in csv.iterrows():
            print(y[0], y[1], y[2], y[3], y[4], y[5], y[6], y[7])
            start = math.floor(y[3])
            end = math.ceil(y[4])
            temp = audio[start * 22050 : end *22050]
            zeros = sum(librosa.zero_crossings(temp))
            duration = end - start
            amplitude_range = max(temp)-min(temp)
            average_amp = np.mean(temp)
            data.append([amplitude_range, average_amp, duration, zeros, y[0], y[1], y[2], y[5]])
    output = pd.DataFrame(data, columns = ['Amp_range','Avg_amp','Duration','Zero_Crossings', 'Species', 'Sex', 'Age', 'Call'])
    return output

# %%
audio_feat_extractor([AJ2])
# Out:
# A. jubatus nan A 0:00 0:01 growl 0 nan
# A. jubatus nan A 0:01 0:05 nan 0 nan
# A. jubatus nan A 0:06 0:11 growl 0 nan
# A. jubatus nan A 0:11 0:16 nan 0 nan
# A. jubatus nan A 0:16 0:19 growl 0 nan
# A. jubatus nan A 0:24 0:35 growl? 0 nan
# A. jubatus nan A 0:49 1:03 growl? 1 nan
# A. jubatus nan A 1:06 1:08 growl 0 nan
# A. jubatus nan A 1:10 1:11 nan 0 nan
# A. jubatus nan A 1:13 1:18 growl 0 nan
# A. jubatus nan A 1:22 1:27 growl 0 nan
# A. jubatus nan A 1:28 1:30 nan 0 nan
# A. jubatus nan A 1:45 1:49 nan 0 nan
# A. jubatus nan A 1:49 2:02 growl? 0 might have some other types of calls mixed in
# A. jubatus nan A 2:07 2:14 growl 0 nan
# A. jubatus nan A 2:16 2:21 growl 0 nan
# A. jubatus nan A 2:28 2:30 growl 0 nan
#     Amp_range       Avg_amp  Duration  Zero_Crossings     Species  Sex Age  \
# 0    0.166116 -3.188780e-05         1             706  A. jubatus  NaN   A
# 1    0.466826 -7.877250e-06         4            3456  A. jubatus  NaN   A
# 2    0.311871  5.425827e-06         5            2984  A. jubatus  NaN   A
# 3    0.386908  2.965167e-06         5            3108  A. jubatus  NaN   A
# 4    0.327264 -2.166283e-05         3            1919  A. jubatus  NaN   A
# 5    0.282358 -7.209107e-06        11            4722  A. jubatus  NaN   A
# 6    0.376489 -4.322251e-06        14            5581  A. jubatus  NaN   A
# 7    0.275109 -1.521657e-05         2            1269  A. jubatus  NaN   A
# 8    0.115904 -8.681753e-05         1             595  A. jubatus  NaN   A
# 9    0.165053 -5.399594e-06         5            2342  A. jubatus  NaN   A
# 10   0.147779 -1.277652e-05         5            1880  A. jubatus  NaN   A
# 11   0.339260  2.011788e-05         2            1239  A. jubatus  NaN   A
# 12   0.564086 -9.388634e-07         4            3686  A. jubatus  NaN   A
# 13   0.370885 -3.714060e-06        13            9331  A. jubatus  NaN   A
# 14   0.850423  5.233508e-07         7            4701  A. jubatus  NaN   A
# 15   0.268877  1.031894e-05         5            3214  A. jubatus  NaN   A
# 16   0.093121 -3.969479e-05         2            1028  A. jubatus  NaN   A
#
#       Call
# 0    growl
# 1      NaN
# 2    growl
# 3      NaN
# 4    growl
# 5   growl?
# 6   growl?
# 7    growl
# 8      NaN
# 9    growl
# 10   growl
# 11     NaN
# 12     NaN
# 13  growl?
# 14   growl
# 15   growl
# 16   growl

# %%
test = feature_extractor(audio, 'Ocelot', 'Unknown', 'Adult',['Main Call', 'Growl'], [18, 30], [22, 35])
test
#Still working on including frequency range, number of partials, and pulses per second
#I may include MFCC and spectral rolloff as well later
# Out:
#    Amp_range       Avg_amp  Duration  Zero_Crossings Species      Sex    Age  \
# 0   0.172491 -5.711619e-06         4            9803  Ocelot  Unknown  Adult
# 1   0.101903  2.583268e-07         5            2306  Ocelot  Unknown  Adult
#
#         Call
# 0  Main Call
# 1      Growl

# %%
audio_string = 'Leopardus_pardalis_Unknown sex_adult_growlS0545_02.wav'
audio, rate = librosa.load(audio_string)
file = audio
species = 'Ocelot'
call = ['Growl', 'growl', 'test', 'meow']
lst_start = [0, 11, 15, 17]
lst_end = [10, 13, 16, 34]

# %%
Audio(audio, rate = rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
