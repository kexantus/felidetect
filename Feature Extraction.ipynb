# %%
import matplotlib.pyplot as plt
from scipy.signal import find_peaks
import numpy as np
from scipy.io import wavfile
import IPython.display as ipd #allows for playing of audio
import librosa
import librosa.display
#allows for spectrographs and other audio manipulation
import pandas as pd
from pydub import AudioSegment
#allows for audio file slicing
import math
from scipy.fft import rfft, rfftfreq
from scipy import signal
# Out:
# C:\Users\exant\anaconda3\lib\site-packages\pydub\utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)

# %% [markdown]
# #Acinonyx files
# aj2 = pd.read_csv(r".\Capstone Files\A. jubatus\AJ2.csv")
# aj3 = pd.read_csv(r".\Capstone Files\A. jubatus\AJ3.csv")
# aj5 = pd.read_csv(r".\Capstone Files\A. jubatus\AJ5.csv")
# aj13 = pd.read_csv(r".\Capstone Files\A. jubatus\AJ13.csv")
# aj2_sound, aj2_rate = librosa.load(r".\Capstone Files\A. jubatus\Acinonyx_jubatus_S0612_02.wav")
# aj3_sound, aj3_rate = librosa.load(r".\Capstone Files\A. jubatus\Acinonyx_jubatus_S1121_03.wav")
# aj5_sound, aj5_rate = librosa.load(r".\Capstone Files\A. jubatus\Acinonyx_jubatus_S1121_05.wav")
# aj13_sound, aj13_rate = librosa.load(r".\Capstone Files\A. jubatus\Acinonyx_jubatus_S1366_13.wav")
# #Tuples
# AJ2 = (aj2, aj2_sound)
# AJ3 = (aj3, aj3_sound)
# AJ5 = (aj5, aj5_sound)
# AJ13 = (aj13, aj13_sound)

# %% [markdown]
# #Caracal files
# C1 = pd.read_csv(r".\Capstone Files\Caracal\C1.csv")
# C1_sound , C1_rate = librosa.load(r".\Capstone Files\Caracal\Caracal_1_Male_Growl+Hiss.wav")
# C2 = pd.read_csv(r".\Capstone Files\Caracal\C2.csv")
# C2_sound , C2_rate = librosa.load(r".\Capstone Files\Caracal\Caracal_2_Male_Growl+Hiss.wav")
# C3 = pd.read_csv(r".\Capstone Files\Caracal\C3.csv")
# C3_sound , C3_rate = librosa.load(r".\Capstone Files\Caracal\Caracal_3___Growl+Hiss.wav")
# C4 = pd.read_csv(r".\Capstone Files\Caracal\C4.csv")
# C4_sound , C4_rate = librosa.load(r".\Capstone Files\Caracal\Caracal_4___Growl.wav")
# C5 = pd.read_csv(r".\Capstone Files\Caracal\C5.csv")
# C5_sound , C5_rate = librosa.load(r".\Capstone Files\Caracal\Caracal_5___Hiss+Growl.wav")
# C6 = pd.read_csv(r".\Capstone Files\Caracal\C6.csv")
# C6_sound , C6_rate = librosa.load(r".\Capstone Files\Caracal\Caracal_6___Hiss+Growl.wav")
# #Tuples
# C1T = (C1, C1_sound)
# C2T = (C2, C2_sound)
# C3T = (C3, C3_sound)
# C4T = (C4, C4_sound)
# C5T = (C5, C5_sound)
# C6T = (C6, C6_sound)

# %% [markdown]
# #Domestica files
# D1 = pd.read_csv(r".\Capstone Files\Domestica\D1.csv")
# D1_sound , D1_rate = librosa.load(r".\Capstone Files\Domestica\Felis_silvestris_f_domestica_S0050_01_pair_adult_hiss,growl.wav")
# D2 = pd.read_csv(r".\Capstone Files\Domestica\D2.csv")
# D2_sound , D2_rate = librosa.load(r".\Capstone Files\Domestica\Felis_silvestris_f_domestica_S0013_01.female_adult_hiss,call,growlwav.wav")
# D3 = pd.read_csv(r".\Capstone Files\Domestica\D3.csv")
# D3_sound , D3_rate = librosa.load(r".\Capstone Files\Domestica\Felis_silvestris_f_domestica_S0002_01_short_female_adult_growl, hiss.wav")
# D4 = pd.read_csv(r".\Capstone Files\Domestica\D4.csv")
# D4_sound, D4_rate = librosa.load(r".\Capstone Files\Domestica\Felis_silvestris_f_domestica_DIG0089_01_male_juvenile_call,purr.wav")
# D5 = pd.read_csv(r".\Capstone Files\Domestica\D5.csv")
# D5_sound, D5_rate = librosa.load(r".\Capstone Files\Domestica\Felis_silvestris_f_domestica_DIG0015_14_male_juvenile_purrpurr.wav")
# #Tuples
# D1T = (D1, D1_sound)
# D2T = (D2, D2_sound)
# D3T = (D3, D3_sound)
# D4T = (D4, D4_sound)
# D5T = (D5, D5_sound)

# %% [markdown]
# #L lynx audio files
# L1 = pd.read_csv(r".\Capstone Files\L. Lynx\L1.csv")
# L1_sound, L1_rate = librosa.load(r".\Capstone Files\L. Lynx\Lynx_lynx_1.wav")
# L2 = pd.read_csv(r".\Capstone Files\L. Lynx\L2.csv")
# L2_sound, L2_rate = librosa.load(r".\Capstone Files\L. Lynx\Lynx_lynx_2.wav")
# L3 = pd.read_csv(r".\Capstone Files\L. Lynx\L3.csv")
# L3_sound, L3_rate = librosa.load(r".\Capstone Files\L. Lynx\Lynx_lynx_3.wav")
# L4 = pd.read_csv(r".\Capstone Files\L. Lynx\L4.csv")
# L4_sound, L4_rate = librosa.load(r".\Capstone Files\L. Lynx\Lynx_lynx_4.wav")
# L5 = pd.read_csv(r".\Capstone Files\L. Lynx\L5.csv")
# L5_sound, L5_rate = librosa.load(r".\Capstone Files\L. Lynx\Lynx_lynx_5.wav")
# L6 = pd.read_csv(r".\Capstone Files\L. Lynx\L6.csv")
# L6_sound, L6_rate = librosa.load(r".\Capstone Files\L. Lynx\Lynx_lynx_6.wav")
# L7 = pd.read_csv(r".\Capstone Files\L. Lynx\L7.csv")
# L7_sound, L7_rate = librosa.load(r".\Capstone Files\L. Lynx\Lynx_lynx_7.wav")
# L8 = pd.read_csv(r".\Capstone Files\L. Lynx\L8.csv")
# L8_sound, L8_rate = librosa.load(r".\Capstone Files\L. Lynx\Lynx_lynx_8.wav")
# L9 = pd.read_csv(r".\Capstone Files\L. Lynx\L9.csv")
# L9_sound, L9_rate = librosa.load(r".\Capstone Files\L. Lynx\Lynx_lynx_9.wav")
# L10 = pd.read_csv(r".\Capstone Files\L. Lynx\L10.csv")
# L10_sound, L10_rate = librosa.load(r".\Capstone Files\L. Lynx\Lynx_lynx_10.wav")
# L11 = pd.read_csv(r".\Capstone Files\L. Lynx\L11.csv")
# L11_sound, L11_rate = librosa.load(r".\Capstone Files\L. Lynx\Lynx_lynx_11.wav")
# L12 = pd.read_csv(r".\Capstone Files\L. Lynx\L12.csv")
# L12_sound, L12_rate = librosa.load(r".\Capstone Files\L. Lynx\Lynx_lynx_12.wav")
# # Tuples
# L1T = (L1, L1_sound)
# L2T = (L2, L2_sound)
# L3T = (L3, L3_sound)
# L4T = (L4, L4_sound)
# L5T = (L5, L5_sound)
# L6T = (L6, L6_sound)
# L7T = (L7, L7_sound)
# L8T = (L8, L8_sound)
# L9T = (L9, L9_sound)
# L10T = (L10, L10_sound)
# L11T = (L11, L11_sound)
# L12T = (L12, L12_sound)

# %% [markdown]
# #Lynx Rufus
# LR1 = pd.read_csv(r".\Capstone Files\L. Rufus\LR1.csv")
# LR1_sound, LR1_rate = librosa.load(r"C:\Users\exant\My Jupyter Files\Capstone\Capstone Files\L. Rufus\LR1.wav")
# LR2 = pd.read_csv(r".\Capstone Files\L. Rufus\LR2.csv")
# LR2_sound, LR2_rate = librosa.load(r".\Capstone Files\L. Rufus\LR2.wav")
# #Tuples
# LR1T = (LR1, LR1_sound)
# LR2T = (LR2, LR2_sound)

# %% [markdown]
# #Leopardus Pardalis
# LP1 = pd.read_csv(r".\Capstone Files\Leopardus\LP1.csv")
# LP1_sound, LP1_rate = librosa.load(r".\Capstone Files\Leopardus\LP1.wav")
# LP2 = pd.read_csv(r".\Capstone Files\Leopardus\LP2.csv")
# LP2_sound, LP2_rate = librosa.load(r".\Capstone Files\Leopardus\LP2.wav")
# LP3 = pd.read_csv(r".\Capstone Files\Leopardus\LP3.csv")
# LP3_sound, LP3_rate = librosa.load(r".\Capstone Files\Leopardus\LP3.wav")
# LP4 = pd.read_csv(r".\Capstone Files\Leopardus\LP4.csv")
# LP4_sound, LP4_rate = librosa.load(r".\Capstone Files\Leopardus\LP4.wav")
# #Tuples
# LP1T = (LP1, LP1_sound)
# LP2T = (LP2, LP2_sound)
# LP3T = (LP3, LP3_sound)
# LP4T = (LP4, LP4_sound)

# %% [markdown]
# CT1 = pd.read_csv(r".\Capstone Files\Catopuma temminckii\CT1.csv")
# CT1_sound, CT1_rate = librosa.load(r".\Capstone Files\Catopuma temminckii\Catopuma_temminckii_V1736_02.wav")
# #Catopuma temminckii audio files
# CT1T = (CT1,CT1_sound)

# %% [markdown]
# FS1 = pd.read_csv(r".\Capstone Files\Felis_silvestris\Felis_Silvestris_S0547_01.csv")
# FS1_sound, FS1_rate = librosa.load(r".\Capstone Files\Felis_silvestris\Felis_silvestris_S0547_01.wav")
# FS2 = pd.read_csv(r".\Capstone Files\Felis_silvestris\Felis_Silvestris_S0595_03.csv")
# FS2_sound, FS2_rate = librosa.load(r".\Capstone Files\Felis_silvestris\Felis_silvestris_S0595_03.wav")
# FS3 = pd.read_csv(r"C:\Users\exant\My Jupyter Files\Capstone\Capstone Files\Felis_silvestris\Felis_silvestris_S0916_03.csv")
# FS3_sound, FS3_rate = librosa.load(r".\Capstone Files\Felis_silvestris\Felis_silvestris_S0916_03.wav")
# FS4 = pd.read_csv(r".\Capstone Files\Felis_silvestris\Felis_Silvestris_S0921_07.csv")
# FS4_sound, FS4_rate = librosa.load(r".\Capstone Files\Felis_silvestris\Felis_silvestris_S0921_07.wav")
# FS5 = pd.read_csv(r".\Capstone Files\Felis_silvestris\Felis_Silvestris_S1042_07.csv")
# FS5_sound, FS5_rate = librosa.load(r".\Capstone Files\Felis_silvestris\Felis_silvestris_S1042_07.wav")
# FS6 = pd.read_csv(r".\Capstone Files\Felis_silvestris\Felis_Silvestris_S1411_07.csv")
# FS6_sound, FS6_rate = librosa.load(r".\Capstone Files\Felis_silvestris\Felis_silvestris_S1411_07.wav")
# FS7 = pd.read_csv(r".\Capstone Files\Felis_silvestris\Felis_Silvestris_S1449_04.csv")
# FS7_sound, FS7_rate = librosa.load(r".\Capstone Files\Felis_silvestris\Felis_silvestris_V1449_04.wav")
# FS8 = pd.read_csv(r".\Capstone Files\Felis_silvestris\Felis_Silvestris_V1502_44.csv")
# FS8_sound, FS8_rate = librosa.load(r".\Capstone Files\Felis_silvestris\Felis_silvestris_V1502_44.wav")
# #Felis silvestris audio files
# FS1T = (FS1,FS1_sound)
# FS2T = (FS2,FS2_sound)
# FS3T = (FS3,FS3_sound)
# FS4T = (FS4,FS4_sound)
# FS5T = (FS5,FS5_sound)
# FS6T = (FS6,FS6_sound)
# FS7T = (FS7,FS7_sound)
# FS8T = (FS8,FS8_sound)

# %% [markdown]
# LS1 = pd.read_csv(r".\Capstone Files\L. Serval\LS1.csv")
# LS1_sound, LS1_rate = librosa.load(r".\Capstone Files\L. Serval\Leptailurus_serval_growl+hiss.wav")
# #L.Serval audio files
# LS1T = (LS1,LS1_sound)

# %%
CLH1 = pd.read_csv(r".\Capstone Files\Pantherinae\CL-Hiss.csv")
CLH1_sound, CLH1_rate = librosa.load(r".\Capstone Files\Pantherinae\CL-Hiss.wav")
#Cloud_Leopard Hiss audio files
CLH1T = (CLH1,CLH1_sound)

# %%
#Cloud Leopard Pursten
CLP1 = pd.read_csv(r".\Capstone Files\Pantherinae\CL-Prusten-1.csv")
CLP1_sound, CLP1_rate = librosa.load(r".\Capstone Files\Pantherinae\CL-Prusten-1.wav")
CLP2 = pd.read_csv(r".\Capstone Files\Pantherinae\CL-Prusten-2.csv")
CLP2_sound, CLP2_rate = librosa.load(r".\Capstone Files\Pantherinae\CL-Prusten-2.wav")
CLP3 = pd.read_csv(r".\Capstone Files\Pantherinae\CL-Prusten-3.csv")
CLP3_sound, CLP3_rate = librosa.load(r".\Capstone Files\Pantherinae\CL-Prusten-3.wav")
CLP4 = pd.read_csv(r".\Capstone Files\Pantherinae\CL-Prusten-4.csv")
CLP4_sound, CLP4_rate = librosa.load(r".\Capstone Files\Pantherinae\CL-Prusten-4.wav")
CLP5 = pd.read_csv(r".\Capstone Files\Pantherinae\CL-Prusten-5.csv")
CLP5_sound, CLP5_rate = librosa.load(r".\Capstone Files\Pantherinae\CL-Prusten-5.wav")
CLP6 = pd.read_csv(r".\Capstone Files\Pantherinae\CL-Prusten-6.csv")
CLP6_sound, CLP6_rate = librosa.load(r".\Capstone Files\Pantherinae\CL-Prusten-6.wav")
CLP7 = pd.read_csv(r".\Capstone Files\Pantherinae\CL-Prusten-7.csv")
CLP7_sound, CLP7_rate = librosa.load(r".\Capstone Files\Pantherinae\CL-Prusten-7.wav")
CLP8 = pd.read_csv(r".\Capstone Files\Pantherinae\CL-Prusten-8.csv")
CLP8_sound, CLP8_rate = librosa.load(r".\Capstone Files\Pantherinae\CL-Prusten-8.wav")
CLP9 = pd.read_csv(r".\Capstone Files\Pantherinae\CL-Prusten-9.csv")
CLP9_sound, CLP9_rate = librosa.load(r".\Capstone Files\Pantherinae\CL-Prusten-9.wav")
CLP10 = pd.read_csv(r".\Capstone Files\Pantherinae\CL-Prusten-10.csv")
CLP10_sound, CLP10_rate = librosa.load(r".\Capstone Files\Pantherinae\CL-Prusten-10.wav")
CLP11 = pd.read_csv(r".\Capstone Files\Pantherinae\CL-Prusten-11.csv")
CLP11_sound, CLP11_rate = librosa.load(r".\Capstone Files\Pantherinae\CL-Prusten-11.wav")
CLP12 = pd.read_csv(r".\Capstone Files\Pantherinae\CL-Prusten-12.csv")
CLP12_sound, CLP12_rate = librosa.load(r".\Capstone Files\Pantherinae\CL-Prusten-12.wav")
CLP13 = pd.read_csv(r".\Capstone Files\Pantherinae\CL-Prusten-13.csv")
CLP13_sound, CLP13_rate = librosa.load(r".\Capstone Files\Pantherinae\CL-Prusten-13.wav")
#Cloud Leopard Pursten audio files
CLP1T = (CLP1,CLP1_sound)
CLP2T = (CLP2,CLP2_sound)
CLP3T = (CLP3,CLP3_sound)
CLP4T = (CLP4,CLP4_sound)
CLP5T = (CLP5,CLP5_sound)
CLP6T = (CLP6,CLP6_sound)
CLP7T = (CLP7,CLP7_sound)
CLP8T = (CLP8,CLP8_sound)
CLP9T = (CLP9,CLP9_sound)
CLP10T = (CLP10,CLP10_sound)
CLP11T = (CLP11,CLP11_sound)
CLP12T = (CLP12,CLP12_sound)
CLP13T = (CLP13,CLP13_sound)

# %%
#Jaguar Prusten
JP1 = pd.read_csv(r".\Capstone Files\Pantherinae\Jaguar-Prusten-1.csv")
JP1_sound, JP1_rate = librosa.load(r".\Capstone Files\Pantherinae\Jaguar-Prusten-1.wav")
JP2 = pd.read_csv(r".\Capstone Files\Pantherinae\Jaguar-Prusten-2.csv")
JP2_sound, JP2_rate = librosa.load(r".\Capstone Files\Pantherinae\Jaguar-Prusten-2.wav")
#Jaguar Prusten audio files
JP1T = (JP1,JP1_sound)
JP2T = (JP2,JP2_sound)

# %%
#Jaguar Roar 
JR1 = pd.read_csv(r".\Capstone Files\Pantherinae\Jaguar-Roar-1.csv")
JR1_sound, JR1_rate = librosa.load(r".\Capstone Files\Pantherinae\Jaguar-Roar-1.wav")
JR2 = pd.read_csv(r".\Capstone Files\Pantherinae\Jaguar-Roar-2.csv")
JR2_sound, JR2_rate = librosa.load(r".\Capstone Files\Pantherinae\Jaguar-Roar-2.wav")
JR3 = pd.read_csv(r".\Capstone Files\Pantherinae\Jaguar-Roar-3.csv")
JR3_sound, JR3_rate = librosa.load(r".\Capstone Files\Pantherinae\Jaguar-Roar-3.wav")
JR4 = pd.read_csv(r".\Capstone Files\Pantherinae\Jaguar-Roar-4.csv")
JR4_sound, JR4_rate = librosa.load(r".\Capstone Files\Pantherinae\Jaguar-Roar-4.wav")
JR5 = pd.read_csv(r".\Capstone Files\Pantherinae\Jaguar-Roar-5.csv")
JR5_sound, JR5_rate = librosa.load(r".\Capstone Files\Pantherinae\Jaguar-Roar-5.wav")
#Jaguar Roar audio files
JR1T = (JR1,JR1_sound)
JR2T = (JR2,JR2_sound)
JR3T = (JR3,JR3_sound)
JR4T = (JR4,JR4_sound)
JR5T = (JR5,JR5_sound)

# %%
#Leopard Roaring
LPR1 = pd.read_csv(r".\Capstone Files\Pantherinae\Leopard roaring sequence 1.csv")
LPR1_sound, LPR1_rate = librosa.load(r".\Capstone Files\Pantherinae\Leopard roaring sequence 1.wav")
LPR2 = pd.read_csv(r".\Capstone Files\Pantherinae\Leopard roaring sequence 2.csv")
LPR2_sound, LPR2_rate = librosa.load(r".\Capstone Files\Pantherinae\Leopard roaring sequence 2.wav")
LPR3 = pd.read_csv(r".\Capstone Files\Pantherinae\Leopard roaring sequence 3.csv")
LPR3_sound, LPR3_rate = librosa.load(r".\Capstone Files\Pantherinae\Leopard roaring sequence 3.wav")
LPR4 = pd.read_csv(r".\Capstone Files\Pantherinae\Leopard roaring sequence 4.csv")
LPR4_sound, LPR4_rate = librosa.load(r".\Capstone Files\Pantherinae\Leopard roaring sequence 4.wav")
LPR5 = pd.read_csv(r".\Capstone Files\Pantherinae\Leopard roaring sequence 5.csv")
LPR5_sound, LPR5_rate = librosa.load(r".\Capstone Files\Pantherinae\Leopard roaring sequence 5.wav")
LPR6 = pd.read_csv(r".\Capstone Files\Pantherinae\Leopard roaring sequence 6.csv")
LPR6_sound, LPR6_rate = librosa.load(r".\Capstone Files\Pantherinae\Leopard roaring sequence 6.wav")
LPR7 = pd.read_csv(r".\Capstone Files\Pantherinae\Leopard roaring sequence 7.csv")
LPR7_sound, LPR7_rate = librosa.load(r".\Capstone Files\Pantherinae\Leopard roaring sequence 7.wav")
LPR8 = pd.read_csv(r".\Capstone Files\Pantherinae\Leopard roaring sequence 8.csv")
LPR8_sound, LPR8_rate = librosa.load(r".\Capstone Files\Pantherinae\Leopard roaring sequence 8.wav")
LPR9 = pd.read_csv(r".\Capstone Files\Pantherinae\Leopard roaring sequence 9.csv")
LPR9_sound, LPR9_rate = librosa.load(r".\Capstone Files\Pantherinae\Leopard roaring sequence 9.wav")
LPR10a = pd.read_csv(r".\Capstone Files\Pantherinae\Leopard roaring sequence 10a.csv")
LPR10a_sound, LPR10a_rate = librosa.load(r".\Capstone Files\Pantherinae\Leopard roaring sequence 10a.wav")
LPR10b = pd.read_csv(r".\Capstone Files\Pantherinae\Leopard roaring sequence 10b.csv")
LPR10b_sound, LPR10b_rate = librosa.load(r".\Capstone Files\Pantherinae\Leopard roaring sequence 10b.wav")
LPR10c = pd.read_csv(r".\Capstone Files\Pantherinae\Leopard roaring sequence 10c.csv")
LPR10c_sound, LPR10c_rate = librosa.load(r".\Capstone Files\Pantherinae\Leopard roaring sequence 10c.wav")
LPR10d = pd.read_csv(r".\Capstone Files\Pantherinae\Leopard roaring sequence 10d.csv")
LPR10d_sound, LPR10d_rate = librosa.load(r".\Capstone Files\Pantherinae\Leopard roaring sequence 10d.wav")
LPR11 = pd.read_csv(r".\Capstone Files\Pantherinae\Leopard roaring sequence 11.csv")
LPR11_sound, LPR11_rate = librosa.load(r".\Capstone Files\Pantherinae\Leopard roaring sequence 11.wav")
LPR12 = pd.read_csv(r".\Capstone Files\Pantherinae\Leopard roaring sequence 12.csv")
LPR12_sound, LPR12_rate = librosa.load(r".\Capstone Files\Pantherinae\Leopard roaring sequence 12.wav")
LPR13 = pd.read_csv(r".\Capstone Files\Pantherinae\Leopard roaring sequence 13.csv")
LPR13_sound, LPR13_rate = librosa.load(r".\Capstone Files\Pantherinae\Leopard roaring sequence 13.wav")
#Leopard Roaring audio files
LPR1T = (LPR1,LPR1_sound)
LPR2T = (LPR2,LPR2_sound)
LPR3T = (LPR3,LPR3_sound)
LPR4T = (LPR4,LPR4_sound)
LPR5T = (LPR5,LPR5_sound)
LPR6T = (LPR6,LPR6_sound)
LPR7T = (LPR7,LPR7_sound)
LPR8T = (LPR8,LPR8_sound)
LPR9T = (LPR9,LPR9_sound)
LPR10aT = (LPR10a,LPR10a_sound)
LPR10bT = (LPR10b,LPR10b_sound)
LPR10cT = (LPR10c,LPR10c_sound)
LPR10dT = (LPR10d,LPR10d_sound)
LPR11T = (LPR11,LPR11_sound)
LPR12T = (LPR12,LPR12_sound)
LPR13T = (LPR13,LPR13_sound)

# %%
#Leopard Growl
LPG1 = pd.read_csv(r".\Capstone Files\Pantherinae\Leopard_growl_2.csv")
LPG1_sound, LPG1_rate = librosa.load(r".\Capstone Files\Pantherinae\Leopard_growl_2.wav")
LPG2 = pd.read_csv(r".\Capstone Files\Pantherinae\Leopard_growl_3.csv")
LPG2_sound, LPG2_rate = librosa.load(r".\Capstone Files\Pantherinae\Leopard_growl_3.wav")
LPG3 = pd.read_csv(r".\Capstone Files\Pantherinae\Leopard_growl_4.csv")
LPG3_sound, LPG3_rate = librosa.load(r".\Capstone Files\Pantherinae\Leopard_growl_4.wav")
#Leopard Growl audio files
LPG1T = (LPG1,LPG1_sound)
LPG2T = (LPG2,LPG2_sound)
LPG3T = (LPG3,LPG3_sound)

# %%
LI1 = pd.read_csv(r".\Capstone Files\Pantherinae\LG1.csv")
LI1_sound, LI1_rate = librosa.load(r".\Capstone Files\Pantherinae\LG1.wav")
LI2 = pd.read_csv(r".\Capstone Files\Pantherinae\LG2.csv")
LI2_sound, LI2_rate = librosa.load(r".\Capstone Files\Pantherinae\LG2.wav")
#LI3 = pd.read_csv(r".\Capstone Files\Pantherinae\LG3 (miss time point) Lion Growl 3 .csv")
#LI3_sound, LI3_rate = librosa.load(r".\Capstone Files\Pantherinae\LG3.wav")
LI7 = pd.read_csv(r".\Capstone Files\Pantherinae\LG7.csv")
LI7_sound, LI7_rate = librosa.load(r".\Capstone Files\Pantherinae\LG7.wav")
LI8 = pd.read_csv(r".\Capstone Files\Pantherinae\LG8.csv")
LI8_sound, LI8_rate = librosa.load(r".\Capstone Files\Pantherinae\LG8.wav")
LI9 = pd.read_csv(r".\Capstone Files\Pantherinae\LG9.csv")
LI9_sound, LI9_rate = librosa.load(r".\Capstone Files\Pantherinae\LG9.wav")
LI10 = pd.read_csv(r".\Capstone Files\Pantherinae\Lion Puff 1.csv")
LI10_sound, LI10_rate = librosa.load(r".\Capstone Files\Pantherinae\Lion Puff 1.wav")

LIR1 = pd.read_csv(r".\Capstone Files\Pantherinae\Lion Roaring Sequence_1.csv")
LIR1_sound, LIR1_rate = librosa.load(r".\Capstone Files\Pantherinae\Lion Roaring Sequence_1.wav")
LIR2 = pd.read_csv(r".\Capstone Files\Pantherinae\Lion Roaring Sequence_2.csv")
LIR2_sound, LIR2_rate = librosa.load(r".\Capstone Files\Pantherinae\Lion Roaring Sequence_2.wav")
LIR3 = pd.read_csv(r".\Capstone Files\Pantherinae\Lion Roaring Sequence_3.csv")
LIR3_sound, LIR3_rate = librosa.load(r".\Capstone Files\Pantherinae\Lion Roaring Sequence_3.wav")
LIR4 = pd.read_csv(r".\Capstone Files\Pantherinae\Lion Roaring Sequence_4.csv")
LIR4_sound, LIR4_rate = librosa.load(r".\Capstone Files\Pantherinae\Lion Roaring Sequence_4.wav")
LIR5 = pd.read_csv(r".\Capstone Files\Pantherinae\Lion Roaring Sequence_5.csv")
LIR5_sound, LIR5_rate = librosa.load(r".\Capstone Files\Pantherinae\Lion Roaring Sequence_5.wav")
LIR6 = pd.read_csv(r".\Capstone Files\Pantherinae\Lion Roaring Sequence_6.csv")
LIR6_sound, LIR6_rate = librosa.load(r".\Capstone Files\Pantherinae\Lion Roaring Sequence_6.wav")
LIR7 = pd.read_csv(r".\Capstone Files\Pantherinae\Lion Roaring Sequence_7.csv")
LIR7_sound, LIR7_rate = librosa.load(r".\Capstone Files\Pantherinae\Lion Roaring Sequence_7.wav")
LIR8 = pd.read_csv(r".\Capstone Files\Pantherinae\Lion Roaring Sequence_8.csv")
LIR8_sound, LIR8_rate = librosa.load(r".\Capstone Files\Pantherinae\Lion Roaring Sequence_8.wav")
LIR9 = pd.read_csv(r".\Capstone Files\Pantherinae\Lion Roaring Sequence_9.csv")
LIR9_sound, LIR9_rate = librosa.load(r".\Capstone Files\Pantherinae\Lion Roaring Sequence_9.wav")
LIR10 = pd.read_csv(r".\Capstone Files\Pantherinae\Lion Roaring Sequence_10.csv")
LIR10_sound, LIR10_rate = librosa.load(r".\Capstone Files\Pantherinae\Lion Roaring Sequence_10.wav")
LIR11 = pd.read_csv(r".\Capstone Files\Pantherinae\Lion Roaring Sequence_11.csv")
LIR11_sound, LIR11_rate = librosa.load(r".\Capstone Files\Pantherinae\Lion Roaring Sequence_11.wav")
LIR12 = pd.read_csv(r".\Capstone Files\Pantherinae\Lion Roaring Sequence_12.csv")
LIR12_sound, LIR12_rate = librosa.load(r".\Capstone Files\Pantherinae\Lion Roaring Sequence_12.wav")
LIR13 = pd.read_csv(r".\Capstone Files\Pantherinae\Lion Roaring Sequence_13.csv")
LIR13_sound, LIR13_rate = librosa.load(r".\Capstone Files\Pantherinae\Lion Roaring Sequence_13.wav")
LIR14 = pd.read_csv(r".\Capstone Files\Pantherinae\Lion Roaring Sequence_14.csv")
LIR14_sound, LIR14_rate = librosa.load(r".\Capstone Files\Pantherinae\Lion Roaring Sequence_14.wav")
LIR15 = pd.read_csv(r".\Capstone Files\Pantherinae\Lion Roaring Sequence_15.csv")
LIR15_sound, LIR15_rate = librosa.load(r".\Capstone Files\Pantherinae\Lion Roaring Sequence_15.wav")
LIR16 = pd.read_csv(r".\Capstone Files\Pantherinae\Lion Roaring Sequence_16.csv")
LIR16_sound, LIR16_rate = librosa.load(r".\Capstone Files\Pantherinae\Lion Roaring Sequence_16.wav")
LIR17 = pd.read_csv(r".\Capstone Files\Pantherinae\Lion Roaring Sequence_17.csv")
LIR17_sound, LIR17_rate = librosa.load(r".\Capstone Files\Pantherinae\Lion Roaring Sequence_17.wav")
LIR18 = pd.read_csv(r".\Capstone Files\Pantherinae\Lion Roaring Sequence_18.csv")
LIR18_sound, LIR18_rate = librosa.load(r".\Capstone Files\Pantherinae\Lion Roaring Sequence_18.wav")
LIR19 = pd.read_csv(r".\Capstone Files\Pantherinae\Lion Roaring Sequence_19.csv")
LIR19_sound, LIR19_rate = librosa.load(r".\Capstone Files\Pantherinae\Lion Roaring Sequence_19.wav")



#Lion audio files
LI1T = (LI1,LI1_sound)
LI2T = (LI2,LI2_sound)
#LI3T = (LI3,LI3_sound)
LI7T = (LI7,LI7_sound)
LI8T = (LI8,LI8_sound)
LI9T = (LI9,LI9_sound)
LI10T = (LI10,LI10_sound)

LIR1T = (LIR1, LIR1_sound)
LIR2T = (LIR2, LIR2_sound)
LIR3T = (LIR3, LIR3_sound)
LIR4T = (LIR4, LIR4_sound)
LIR5T = (LIR5, LIR5_sound)
LIR6T = (LIR6, LIR6_sound)
LIR7T = (LIR7, LIR7_sound)
LIR8T = (LIR8, LIR8_sound)
LIR9T = (LIR9, LIR9_sound)
LIR10T = (LIR10, LIR10_sound)
LIR11T = (LIR11, LIR11_sound)
LIR12T = (LIR12, LIR12_sound)
LIR13T = (LIR13, LIR13_sound)
LIR14T = (LIR14, LIR14_sound)
LIR15T = (LIR15, LIR15_sound)
LIR16T = (LIR16, LIR16_sound)
LIR17T = (LIR17, LIR17_sound)
LIR18T = (LIR18, LIR18_sound)
LIR19T = (LIR19, LIR19_sound)

# %%
#Leopard

LO1 = pd.read_csv(r".\Capstone Files\Pantherinae\LO1.csv")
LO1_sound, LO1_rate = librosa.load(r".\Capstone Files\Pantherinae\LO1.wav")
LO2 = pd.read_csv(r".\Capstone Files\Pantherinae\LO2.csv")
LO2_sound, LO2_rate = librosa.load(r".\Capstone Files\Pantherinae\LO2.wav")
LO3 = pd.read_csv(r".\Capstone Files\Pantherinae\LO3.csv")
LO3_sound, LO3_rate = librosa.load(r".\Capstone Files\Pantherinae\LO3.wav")
LO4 = pd.read_csv(r".\Capstone Files\Pantherinae\LO4.csv")
LO4_sound, LO4_rate = librosa.load(r".\Capstone Files\Pantherinae\LO4.wav")

LO1T = (LO1, LO1_sound)
LO2T = (LO2, LO2_sound)
LO3T = (LO3, LO3_sound)
LO4T = (LO4, LO4_sound)

# %%
#Snow leopard

SL1 = pd.read_csv(r".\Capstone Files\Pantherinae\Snow Leopard Mew 1.csv")
SL1_sound, SL1_rate = librosa.load(r".\Capstone Files\Pantherinae\Snow Leopard Mew_1.wav")
SL2 = pd.read_csv(r".\Capstone Files\Pantherinae\Snow Leopard Prusten_1.csv")
SL2_sound, SL2_rate = librosa.load(r".\Capstone Files\Pantherinae\Snow Leopard Prusten_1.wav")
SL3 = pd.read_csv(r".\Capstone Files\Pantherinae\Snow Leopard Prusten_2.csv")
SL3_sound, SL3_rate = librosa.load(r".\Capstone Files\Pantherinae\Snow Leopard Prusten_2.wav")

SL1T = (SL1, SL1_sound)
SL2T = (SL2, SL2_sound)
SL3T = (SL3, SL3_sound)

# %% [markdown]
# #Tiger
#
# T1 = pd.read_csv(r".\Capstone Files\Tiger\Tiger_1.csv")
# T1_sound, T1_rate = librosa.load(r".\Capstone Files\Tiger\Tiger_1.wav")
# T2 = pd.read_csv(r".\Capstone Files\Tiger\Tiger_2.csv")
# T2_sound, T2_rate = librosa.load(r".\Capstone Files\Tiger\Tiger_2.wav")
#
# T1T = (T1, T1_sound)
# T2T = (T2, T2_sound)

# %%
audio_list = [CLH1T, 
              CLP1T, CLP2T, CLP3T, CLP4T, CLP5T, CLP6T, CLP7T, CLP8T, CLP9T, CLP10T, CLP11T, CLP12T, CLP13T, 
              JP1T, JP2T, 
              JR1T, JR2T, JR3T, JR4T, JR5T, 
              LPR1T, LPR2T, LPR3T, LPR4T, LPR5T, LPR6T, LPR7T, LPR8T, LPR9T, LPR10aT, LPR10bT, LPR10cT, LPR10dT, LPR11T, LPR12T, LPR13T, 
              LPG1T, LPG2T, LPG3T,
              LO1T,LO2T,LO3T,LO4T,
              SL1T, SL2T,SL3T,
              LI1T, LI2T, LI7T,LI8T, LI9T, LI10T,
              LIR1T, LIR2T, LIR3T, LIR4T, LIR5T, LIR6T, LIR7T, LIR8T,LIR9T,LIR10T,LIR11T,LIR12T, LIR13T, LIR14T,LIR15T,LIR16T,LIR17T,LIR18T,LIR19T
             ]

'''
audio_list = [AJ2, AJ3, AJ5, AJ13,
              C1T, C2T, C3T, C4T, C5T, C6T, 
              D1T, D2T, D3T, D4T, D5T,
              LP1T, LP2T, LP3T, LP4T, 
              CT1T, 
              FS1T, FS2T, FS3T, FS4T, FS5T, FS6T, FS7T, FS8T,
              LS1T, 
              CLH1T, 
              CLP1T, CLP2T, CLP3T, CLP4T, CLP5T, CLP6T, CLP7T, CLP8T, CLP9T, CLP10T, CLP11T, CLP12T, CLP13T, 
              JP1T, JP2T, 
              JR1T, JR2T, JR3T, JR4T, JR5T, 
              LPR1T, LPR2T, LPR3T, LPR4T, LPR5T, LPR6T, LPR7T, LPR8T, LPR9T, LPR10aT, LPR10bT, LPR10cT, LPR10dT, LPR11T, LPR12T, LPR13T, 
              LPG1T, LPG2T, LPG3T,
              LO1T,LO2T,LO3T,LO4T,
              SL1T, SL2T,SL3T,
              L1T, L2T, L3T, L4T, L5T, L6T, L7T, L8T, L9T, L10T, L11T, L12T,
              LR1T, LR2T,
              LI1T, LI2T, LI7T,LI8T, LI9T, LI10T,
              LIR1T, LIR2T, LIR3T, LIR4T, LIR5T, LIR6T, LIR7T, LIR8T,LIR9T,LIR10T,LIR11T,LIR12T, LIR13T, LIR14T,LIR15T,LIR16T,LIR17T,LIR18T,LIR19T
             ]
'''
# Out:
# '\naudio_list = [AJ2, AJ3, AJ5, AJ13,\n              C1T, C2T, C3T, C4T, C5T, C6T, \n              D1T, D2T, D3T, D4T, D5T,\n              LP1T, LP2T, LP3T, LP4T, \n              CT1T, \n              FS1T, FS2T, FS3T, FS4T, FS5T, FS6T, FS7T, FS8T,\n              LS1T, \n              CLH1T, \n              CLP1T, CLP2T, CLP3T, CLP4T, CLP5T, CLP6T, CLP7T, CLP8T, CLP9T, CLP10T, CLP11T, CLP12T, CLP13T, \n              JP1T, JP2T, \n              JR1T, JR2T, JR3T, JR4T, JR5T, \n              LPR1T, LPR2T, LPR3T, LPR4T, LPR5T, LPR6T, LPR7T, LPR8T, LPR9T, LPR10aT, LPR10bT, LPR10cT, LPR10dT, LPR11T, LPR12T, LPR13T, \n              LPG1T, LPG2T, LPG3T,\n              LO1T,LO2T,LO3T,LO4T,\n              SL1T, SL2T,SL3T,\n              L1T, L2T, L3T, L4T, L5T, L6T, L7T, L8T, L9T, L10T, L11T, L12T,\n              LR1T, LR2T,\n              LI1T, LI2T, LI7T,LI8T, LI9T, LI10T,\n              LIR1T, LIR2T, LIR3T, LIR4T, LIR5T, LIR6T, LIR7T, LIR8T,LIR9T,LIR10T,LIR11T,LIR12T, LIR13T, LIR14T,LIR15T,
# ...

# %%
def frequency_range(audiofile):
    N= len(audiofile)
    y = np.abs(rfft(audiofile))
    x = rfftfreq(N, 1/ 22050)
    tup = (x, y)
    lst = []
    for x in range(len(tup[0])):
        if tup[1][x] > 2.5:
            lst.append(tup[0][x])
    freq_range = max(lst) - min(lst)
    return freq_range

# %%
def top_freq(file):
    f, t, mag = librosa.reassigned_spectrogram(file)
    mag_db = librosa.power_to_db(mag)
    freqs = [0]*len(f[0])
    for y in range(len(f[0])):
        for x in range(len(f)):
            if mag_db[x][y] > -10:
                freqs[y] = f[x][y]
    return freqs

# %%
def pulses(file):
    #Find max
    peaks = find_peaks(file, height = 0, prominence = 0.01)
    max_height = peaks[1]['peak_heights'] #array of the heights of  peaks
    pulse = len(peaks[0])/(len(file)/22050)
    return pulse

# %%
def partials(file):
    count = 0
    mags, freqs, line = plt.magnitude_spectrum(file, 22050)
    for i in range(len(mags)):
        if i > 100 and i <= (len(mags)-102):
            previous = [mags[i-x] for x in range(1,100)]
            post = [mags[i+x] for x in range(1,100)]
            if mags[i] > max(previous) and mags[i] > max(post) and mags[i] > 0.0005:
                count += 1
    return count

# %%
#Pass in a list of tuples, containing two items, the first being a dataframe of the times and the second being the audio file
def audio_feat_extractor(lst_tup):
    data = []
    for tup in lst_tup:
        csv = tup[0]
        audio = tup[1]
        for x, y in csv.iterrows():
            sr = 22050
            start = math.floor(y[3])
            end = math.ceil(y[4])
            temp = audio[start * 22050 : end *22050]
            zeros = sum(librosa.zero_crossings(temp))
            duration = end - start
            positive = np.absolute(temp)
            amplitude_range = max(positive)-min(positive)
            average_amp = np.mean(positive)
            range_freq = frequency_range(temp)
            pulse = pulses(temp)
            partial = partials(temp)
            mfcc = np.mean(librosa.feature.mfcc(y=temp, sr=22050, n_mfcc=40))
            S, phase = librosa.magphase(librosa.stft(temp))
            stft = np.abs(librosa.stft(temp))
            rolloff = np.mean(librosa.feature.spectral_rolloff(S=S, sr=22050))
            mel = np.mean(librosa.feature.melspectrogram(y=temp, sr=22050))
            contrast = np.mean(librosa.feature.spectral_contrast(S=stft, sr=22050))
            chroma = np.mean(librosa.feature.chroma_stft(S=stft, sr=22050))
            tempogram = np.mean(librosa.feature.tempogram(y=temp, sr=sr))
            tonnetz = np.mean(librosa.feature.tonnetz(y=temp,sr=sr))
            rms = np.mean(librosa.feature.rms(y=temp))
            
            data.append([y[8], y[9], duration, zeros, amplitude_range, average_amp, range_freq, pulse, 
                         mfcc, rolloff, mel, contrast, chroma, tempogram, tonnetz, partial, rms, y[1], y[2], y[0], y[5]])
    
    
    output = pd.DataFrame(data, columns = ['File Name', 'Source', 'Duration_in_Sec', 'Zero_Crossings', 'Amp_range','Avg_amp', 'Freq_range','Pulses_per_Sec', 
                                           'Mean_MFCC', 'Mean_Spectral Rolloff', 'Mean_Melspectrogram','Mean_Spectral Contrast',
                                           'Mean_Chromagram', 'Mean_Tempogram', 'Mean_Tonnetz', 'Partials', 'Mean RMS', 'Sex','Age','Species', 'Call'])
    
    return output

# %%
features_dataframe = audio_feat_extractor(audio_list)
# Out:
# C:\Users\exant\anaconda3\lib\site-packages\librosa\core\spectrum.py:222: UserWarning: n_fft=1024 is too small for input signal of length=690
#   warnings.warn(
# C:\Users\exant\anaconda3\lib\site-packages\librosa\core\spectrum.py:222: UserWarning: n_fft=1024 is too small for input signal of length=690
#   warnings.warn(
# C:\Users\exant\anaconda3\lib\site-packages\librosa\core\spectrum.py:222: UserWarning: n_fft=1024 is too small for input signal of length=345
#   warnings.warn(
# C:\Users\exant\anaconda3\lib\site-packages\librosa\core\spectrum.py:222: UserWarning: n_fft=1024 is too small for input signal of length=690
#   warnings.warn(
# C:\Users\exant\anaconda3\lib\site-packages\librosa\core\spectrum.py:222: UserWarning: n_fft=1024 is too small for input signal of length=345
#   warnings.warn(
# C:\Users\exant\anaconda3\lib\site-packages\librosa\core\spectrum.py:222: UserWarning: n_fft=1024 is too small for input signal of length=690
#   warnings.warn(
# ...

# %%
features_dataframe.head()
# Out:
#   File Name                   Source  Duration_in_Sec  Zero_Crossings  \
# 0   CL-Hiss  wildside sabrina tiktok                2            3052
# 1   CL-Hiss  wildside sabrina tiktok                1            1649
# 2   CL-Hiss  wildside sabrina tiktok                1            1265
# 3   CL-Hiss  wildside sabrina tiktok                1            2671
# 4   CL-Hiss  wildside sabrina tiktok                1            1744
#
#    Amp_range   Avg_amp  Freq_range  Pulses_per_Sec  Mean_MFCC  \
# 0   0.068885  0.006089      3921.0           404.5  -7.268548
# 1   0.067508  0.008768      2364.0           546.0  -6.702535
# 2   0.177508  0.009763      2137.0           461.0  -6.511350
# 3   0.047844  0.007377      4015.0           987.0  -6.980524
# 4   0.063522  0.007763      2487.0           628.0  -5.948235
#
#    Mean_Spectral Rolloff  ...  Mean_Spectral Contrast  Mean_Chromagram  \
# 0            3364.872373  ...               19.925640         0.810778
# ...

# %%
features_dataframe.to_csv('features.csv', index=False)
