# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.io import wavfile
from IPython.display import Audio
#allows for playing of audio
import librosa
import librosa.display
#allows for spectrographs and other audio manipulation
import pandas as pd
from pydub import AudioSegment
#allows for audio file slicing
import math

# %%
aj2 = pd.read_csv(r"C:\Users\njfur\Desktop\Capstone Project\A. jubatus\AJ2.csv")
aj3 = pd.read_csv(r"C:\Users\njfur\Desktop\Capstone Project\A. jubatus\AJ3.csv")
aj5 = pd.read_csv(r"C:\Users\njfur\Desktop\Capstone Project\A. jubatus\AJ5.csv")
aj13 = pd.read_csv(r"C:\Users\njfur\Desktop\Capstone Project\A. jubatus\AJ13.csv")
aj2_sound, aj2_rate = librosa.load(r"C:\Users\njfur\Desktop\Capstone Project\A. jubatus\Acinonyx_jubatus_S0612_02.wav")
aj3_sound, aj3_rate = librosa.load(r"C:\Users\njfur\Desktop\Capstone Project\A. jubatus\Acinonyx_jubatus_S1121_03.wav")
aj5_sound, aj5_rate = librosa.load(r"C:\Users\njfur\Desktop\Capstone Project\A. jubatus\Acinonyx_jubatus_S1121_05.wav")
aj13_sound, aj13_rate = librosa.load(r"C:\Users\njfur\Desktop\Capstone Project\A. jubatus\Acinonyx_jubatus_S1366_13.wav")
#Acinonyx files

# %%
AJ5[0].head()
# Out:
#      Species  Sex (if known) Age (if known)  Start Time  End Time  \
# 0  A. jubatus              P              A           1         8
# 1  A. jubatus              P              A          12        13
# 2  A. jubatus              P              A          18        27
# 3  A. jubatus              P              A          30        32
# 4  A. jubatus              P              A          40        41
#
#   Type of Call  Quality of Segment Notes
# 0          NaN                   0   NaN
# 1          NaN                   0   NaN
# 2       growl?                   1   NaN
# 3       growl?                   0   NaN
# 4       growl?                   0   NaN

# %%
AJ2 = (aj2, aj2_sound)
AJ3 = (aj3, aj3_sound)
AJ5 = (aj5, aj5_sound)
AJ13 = (aj13, aj13_sound)
#Acinonyx files continued

# %%
C1 = pd.read_csv(r"C:\Users\njfur\Desktop\Capstone Project\Caracal\C1.csv")
C1_sound , C1_rate = librosa.load(r"C:\Users\njfur\Desktop\Capstone Project\Caracal\Caracal_1_Male_Growl+Hiss.wav")
C2 = pd.read_csv(r"C:\Users\njfur\Desktop\Capstone Project\Caracal\C2.csv")
C2_sound , C2_rate = librosa.load(r"C:\Users\njfur\Desktop\Capstone Project\Caracal\Caracal_2_Male_Growl+Hiss.wav")
C3 = pd.read_csv(r"C:\Users\njfur\Desktop\Capstone Project\Caracal\C3.csv")
C3_sound , C3_rate = librosa.load(r"C:\Users\njfur\Desktop\Capstone Project\Caracal\Caracal_3___Growl+Hiss.wav")
C4 = pd.read_csv(r"C:\Users\njfur\Desktop\Capstone Project\Caracal\C4.csv")
C4_sound , C4_rate = librosa.load(r"C:\Users\njfur\Desktop\Capstone Project\Caracal\Caracal_4___Growl.wav")
C5 = pd.read_csv(r"C:\Users\njfur\Desktop\Capstone Project\Caracal\C5.csv")
C5_sound , C5_rate = librosa.load(r"C:\Users\njfur\Desktop\Capstone Project\Caracal\Caracal_5___Hiss+Growl.wav")
C6 = pd.read_csv(r"C:\Users\njfur\Desktop\Capstone Project\Caracal\C6.csv")
C6_sound , C6_rate = librosa.load(r"C:\Users\njfur\Desktop\Capstone Project\Caracal\Caracal_6___Hiss+Growl.wav")
#Caracal files
C1T = (C1, C1_sound)
C2T = (C2, C2_sound)
C3T = (C3, C3_sound)
C4T = (C4, C4_sound)
C5T = (C5, C5_sound)
C6T = (C6, C6_sound)

# %%
D1 = pd.read_csv(r"C:\Users\njfur\Desktop\Capstone Project\Domestica\D1.csv")
D1_sound , D1_rate = librosa.load(r"C:\Users\njfur\Desktop\Capstone Project\Domestica\Felis_silvestris_f_domestica_S0050_01_pair_adult_hiss,growl.wav")
D2 = pd.read_csv(r"C:\Users\njfur\Desktop\Capstone Project\Domestica\D2.csv")
D2_sound , D2_rate = librosa.load(r"C:\Users\njfur\Desktop\Capstone Project\Domestica\Felis_silvestris_f_domestica_S0013_01.female_adult_hiss,call,growlwav.wav")
D3 = pd.read_csv(r"C:\Users\njfur\Desktop\Capstone Project\Domestica\D3.csv")
D3_sound , D3_rate = librosa.load(r"C:\Users\njfur\Desktop\Capstone Project\Domestica\Felis_silvestris_f_domestica_S0002_01_short_female_adult_growl, hiss.wav")
D4 = pd.read_csv(r"C:\Users\njfur\Desktop\Capstone Project\Domestica\D4.csv")
D4_sound, D4_rate = librosa.load(r"C:\Users\njfur\Desktop\Capstone Project\Domestica\Felis_silvestris_f_domestica_DIG0089_01_male_juvenile_call,purr.wav")
D5 = pd.read_csv(r"C:\Users\njfur\Desktop\Capstone Project\Domestica\D5.csv")
D5_sound, D5_rate = librosa.load(r"C:\Users\njfur\Desktop\Capstone Project\Domestica\Felis_silvestris_f_domestica_DIG0015_14_male_juvenile_purrpurr.wav")
#Domestica files
D1T = (D1, D1_sound)
D2T = (D2, D2_sound)
D3T = (D3, D3_sound)
D4T = (D4, D4_sound)
D5T = (D5, D5_sound)

# %%
L1 = pd.read_csv(r"C:\Users\njfur\Desktop\Capstone Project\L. Lynx\L1.csv")
L1_sound, L1_rate = librosa.load(r"C:\Users\njfur\Desktop\Capstone Project\L. Lynx\Lynx_lynx_1.wav")
L2 = pd.read_csv(r"C:\Users\njfur\Desktop\Capstone Project\L. Lynx\L2.csv")
L2_sound, L2_rate = librosa.load(r"C:\Users\njfur\Desktop\Capstone Project\L. Lynx\Lynx_lynx_2.wav")
L3 = pd.read_csv(r"C:\Users\njfur\Desktop\Capstone Project\L. Lynx\L3.csv")
L3_sound, L3_rate = librosa.load(r"C:\Users\njfur\Desktop\Capstone Project\L. Lynx\Lynx_lynx_3.wav")
L4 = pd.read_csv(r"C:\Users\njfur\Desktop\Capstone Project\L. Lynx\L4.csv")
L4_sound, L4_rate = librosa.load(r"C:\Users\njfur\Desktop\Capstone Project\L. Lynx\Lynx_lynx_4.wav")
L5 = pd.read_csv(r"C:\Users\njfur\Desktop\Capstone Project\L. Lynx\L5.csv")
L5_sound, L5_rate = librosa.load(r"C:\Users\njfur\Desktop\Capstone Project\L. Lynx\Lynx_lynx_5.wav")
L6 = pd.read_csv(r"C:\Users\njfur\Desktop\Capstone Project\L. Lynx\L6.csv")
L6_sound, L6_rate = librosa.load(r"C:\Users\njfur\Desktop\Capstone Project\L. Lynx\Lynx_lynx_6.wav")
L7 = pd.read_csv(r"C:\Users\njfur\Desktop\Capstone Project\L. Lynx\L7.csv")
L7_sound, L7_rate = librosa.load(r"C:\Users\njfur\Desktop\Capstone Project\L. Lynx\Lynx_lynx_7.wav")
L8 = pd.read_csv(r"C:\Users\njfur\Desktop\Capstone Project\L. Lynx\L8.csv")
L8_sound, L8_rate = librosa.load(r"C:\Users\njfur\Desktop\Capstone Project\L. Lynx\Lynx_lynx_8.wav")
L9 = pd.read_csv(r"C:\Users\njfur\Desktop\Capstone Project\L. Lynx\L9.csv")
L9_sound, L9_rate = librosa.load(r"C:\Users\njfur\Desktop\Capstone Project\L. Lynx\Lynx_lynx_9.wav")
L10 = pd.read_csv(r"C:\Users\njfur\Desktop\Capstone Project\L. Lynx\L10.csv")
L10_sound, L10_rate = librosa.load(r"C:\Users\njfur\Desktop\Capstone Project\L. Lynx\Lynx_lynx_10.wav")
L11 = pd.read_csv(r"C:\Users\njfur\Desktop\Capstone Project\L. Lynx\L11.csv")
L11_sound, L11_rate = librosa.load(r"C:\Users\njfur\Desktop\Capstone Project\L. Lynx\Lynx_lynx_11.wav")
L12 = pd.read_csv(r"C:\Users\njfur\Desktop\Capstone Project\L. Lynx\L12.csv")
L12_sound, L12_rate = librosa.load(r"C:\Users\njfur\Desktop\Capstone Project\L. Lynx\Lynx_lynx_12.wav")
#L lynx audio files
L1T = (L1, L1_sound)
L2T = (L2, L2_sound)
L3T = (L3, L3_sound)
L4T = (L4, L4_sound)
L5T = (L5, L5_sound)
L6T = (L6, L6_sound)
L7T = (L7, L7_sound)
L8T = (L8, L8_sound)
L9T = (L9, L9_sound)
L10T = (L10, L10_sound)
L11T = (L11, L11_sound)
L12T = (L12, L12_sound)

# %%
LR1 = pd.read_csv(r"C:\Users\njfur\Desktop\Capstone Project\L. Rufus\LR1.csv")
LR1_sound, LR1_rate = librosa.load(r"C:\Users\njfur\Desktop\Capstone Project\L. Rufus\LR1.wav")
LR2 = pd.read_csv(r"C:\Users\njfur\Desktop\Capstone Project\L. Rufus\LR2.csv")
LR2_sound, LR2_rate = librosa.load(r"C:\Users\njfur\Desktop\Capstone Project\L. Rufus\LR2.wav")
#Lynx Rufus
LR1T = (LR1, LR1_sound)
LR2T = (LR2, LR2_sound)

# %%
LP1 = pd.read_csv(r"C:\Users\njfur\Desktop\Capstone Project\Leopardus\LP1.csv")
LP1_sound, LP1_rate = librosa.load(r"C:\Users\njfur\Desktop\Capstone Project\Leopardus\LP1.wav")
LP2 = pd.read_csv(r"C:\Users\njfur\Desktop\Capstone Project\Leopardus\LP2.csv")
LP2_sound, LP2_rate = librosa.load(r"C:\Users\njfur\Desktop\Capstone Project\Leopardus\LP2.wav")
LP3 = pd.read_csv(r"C:\Users\njfur\Desktop\Capstone Project\Leopardus\LP3.csv")
LP3_sound, LP3_rate = librosa.load(r"C:\Users\njfur\Desktop\Capstone Project\Leopardus\LP3.wav")
LP4 = pd.read_csv(r"C:\Users\njfur\Desktop\Capstone Project\Leopardus\LP4.csv")
LP4_sound, LP4_rate = librosa.load(r"C:\Users\njfur\Desktop\Capstone Project\Leopardus\LP4.wav")
#Leopardus Pardalis
LP1T = (LP1, LP1_sound)
LP2T = (LP2, LP2_sound)
LP3T = (LP3, LP3_sound)
LP4T = (LP4, LP4_sound)

# %%
audio_list = [AJ2, AJ3, AJ5, AJ13, D1T, D2T, D3T, D4T, D5T, C1T, C2T, C3T, C4T, C5T, C6T, L1T, L2T, L3T, L4T, L5T, L6T,
            L7T, L8T, L9T, L10T, L11T, L12T, LR1T, LR2T, LP1T, LP2T, LP3T, LP4T]

# %%
#Pass in a list of tuples, each tuple should contain two items, the first item will be the dataframe of the times
#the second item should be the audio file itself
def audio_feat_extractor(lst_tup):
    data = []
    for tup in lst_tup:
        csv = tup[0]
        audio = tup[1]
        for x, y in csv.iterrows():
            print(y[0], y[1], y[2], y[3], y[4], y[5], y[6], y[7])
            start = math.floor(y[3])
            end = math.ceil(y[4])
            temp = audio[start * 22050 : end *22050]
            zeros = sum(librosa.zero_crossings(temp))
            duration = end - start
            amplitude_range = max(temp)-min(temp)
            average_amp = np.mean(temp)
            data.append([amplitude_range, average_amp, duration, zeros, y[0], y[1], y[2], y[5]])
    output = pd.DataFrame(data, columns = ['Amp_range','Avg_amp','Duration','Zero_Crossings', 'Species', 'Sex', 'Age', 'Call'])
    return output

# %%
features_dataframe = audio_feat_extractor(audio_list)
# Out:
# A. jubatus nan A 0 1 growl 0 nan
# A. jubatus nan A 1 5 nan 0 nan
# A. jubatus nan A 6 11 growl 0 nan
# A. jubatus nan A 11 16 nan 0 nan
# A. jubatus nan A 16 19 growl 0 nan
# A. jubatus nan A 24 35 growl? 0 nan
# A. jubatus nan A 49 63 growl? 1 nan
# A. jubatus nan A 66 68 growl 0 nan
# A. jubatus nan A 70 71 nan 0 nan
# A. jubatus nan A 73 78 growl 0 nan
# A. jubatus nan A 82 87 growl 0 nan
# A. jubatus nan A 88 90 nan 0 nan
# A. jubatus nan A 105 109 nan 0 nan
# A. jubatus nan A 109 122 growl? 0 might have some other types of calls mixed in
# A. jubatus nan A 127 134 growl 0 nan
# A. jubatus nan A 136 141 growl 0 nan
# A. jubatus nan A 148 150 growl 0 nan
# A. jubatus G (1 M and 2F) A 2 3 growl 0 nan
# A. jubatus G (1 M and 2F) A 3 8 hiss 0 nan
# A. jubatus G (1 M and 2F) A 8 10 growl 0 nan
# A. jubatus G (1 M and 2F) A 12 16 growl 0 nan
# A. jubatus G (1 M and 2F) A 18 23 growl 0 high-pitched
# A. jubatus G (1 M and 2F) A 29 31 growl 1 nan
# ...

# %%
features_dataframe.to_csv('features.csv')
